# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(["science", "notebook", "grid"])

# %%
x = np.linspace(-1, 1)
y = x**2
plt.plot(x, y)

# %%
x = np.linspace(-1, 1)
y = x**3
plt.plot(x, y)

# %%
x = np.linspace(-2*np.pi, 2*np.pi)
y = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y)
plt.plot(x, y2)
